# %%
# Regressione lineare semplice in Python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Dati di esempio
data = {
    'TV': [230.1, 44.5, 17.2, 151.5, 180.8, 8.7, 57.5, 120.2],
    'Sales': [22.1, 10.4, 9.3, 18.5, 12.9, 7.2, 11.8, 17.1]
}
df = pd.DataFrame(data, columns=['TV', 'Sales'])

# Separazione variabili
X = df[['TV']]      # variabile indipendente
y = df['Sales']     # variabile dipendente

# Creazione e addestramento del modello
model = LinearRegression()
model.fit(X, Y)
# Il modello va addestramo mediante metodo fit

# Predizioni
y_pred = model.predict(X)

# Coefficienti
print("Intercetta (beta_0): ", model.intercept_)
print("Coefficiente (beta_1): ", model.coef_[0])
# Dopo aver addestrato il modello di procede con la predizione e il calcolo dei coefficienti

# Valutazione
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print("\nMean Squared Error (MSE): ", mse)
print("R^2 Score (R2): ", r2)
# Per valutare il modello si utilizzano i metodi per lo scarto quadratico medio e r^2 score

# Visualizzazione
plt.scatter(X, y, color='blue', label='Dati reali')
plt.plot(X, y_pred, color='red', linewidth=2, label='Retta di regressione')
plt.title('Regressione lineare semplice')
plt.xlabel('Investimento in TV')
plt.ylabel('Vendite')
plt.legend()
plt.show()
# Out:
# Intercetta (beta_0):  8.080985043454628
# Coefficiente (beta_1):  0.05509206619662303
#
# Mean Squared Error (MSE):  5.0655735818686844
# R^2 Score (R2):  0.7772134846723825
