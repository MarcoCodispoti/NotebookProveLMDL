# %%
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris
import umap     # Assicuriamoci di averlo installato
import seaborn as sns
import matplotlib.pyplot as plt

# Usiamo il dataset Iris o Digits per vedere la differenza
iris = load_iris()
X = iris.data
y = iris.target
X_scaled = StandardScaler().fit_transform(X)


# 1 t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# 2 UMAP
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42)
X_umap = reducer.fit_transform(X_scaled)

# Visualizzazione
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

sns.scatterplot(x=X_tsne[:,0], y=X_tsne[:,1], hue=y, palette='viridis', ax=ax1)
ax1.set_title("visualizzazione t-SNE")

sns.scatterplot(x=X_umap[:,0], y=X_umap[:,1], hue=y, palette='magma', ax=ax2)
ax2.set_title("Visualizzazione UMAP")
plt.show()
# Out:
# /Users/marco/PycharmProjects/NotebookProveLMDL/.venv/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
